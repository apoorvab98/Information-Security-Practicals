# %%
import pandas as pd        
from matplotlib import pyplot as plt
import math
message = ''
# fn = input('Enter pAth : ')
# with open(fn,'r') as f:
#     for e in f.read():
message = "hello hello helllo"

# print('letter frequency histogram : ')
freq = {}
for e in message:
    try:
        freq[e]+=1
    except:
        freq[e]=1

df = pd.DataFrame({'letter':list(freq.keys()),'frequency':list(freq.values())})
ax = df.plot.bar(x='letter', y='frequency', rot=0)
plt.show()
